# %%
import vaex

# %%
path = "/data/_DUMP/marital_status_csv_uid/dump_parquet/*.parquet"

# %%
path3 = "/data/download_hdfs/debug_data/debug_media_parser/centralized_get_visitor_identified_2019_11_29_06/*.parquet"

# %%
path_csv = "/data/_DUMP/marital_status_csv_uid/ALL.csv"

# %%
df =  vaex.open(path3)

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/miniconda3/envs/vaex/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ~/miniconda3/envs/vaex/lib/python3.8/site-packages/vaex/dataframe.py in _repr_mimebundle_(self, include, exclude, **kwargs)
#    3689         # TODO: optimize, since we use the same data in both versions
#    3690         # TODO: include latex version
# -> 3691         return {'text/html':self._head_and_tail_table(format='html'), 'text/plain': self._head_and_tail_table(format='plain')}
#    3692
#    3693     def _repr_html_(self):
#
# ...

# %%
df2 =  vaex.read_csv(path_csv)

# %%
df2
# Out:
# #            148
# 0            42468
# 1            67753
# 2            140021
# 3            253765
# 4            286521
# ...          ...
# 133,161,928  283773480
# 133,161,929  283773558
# 133,161,930  283774261
# 133,161,931  283774640
# 133,161,932  1500218480
